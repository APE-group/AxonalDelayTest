# %%
from test_stdp import *

if __name__ == "__main__":
    test_stdp_main()
# Out:
# STDP summary logged to stdp_summary.csv
# --------------------------------------------------
# FINAL DIAGNOSTIC SUMMARY
# For each synapse, we print: axon_delay_ms, dend_delay_ms, #changes, init, final => event list:
# Synapse 1: axon_delay_ms=5.0, dend_delay_ms=0.1, #changes=2, init=39.500, final=39.494 => (NoSpikes, dt_ms=0.000, dW=0.000, W=39.500) (pre_spike_ms=204.600, post_spike_ms=194.600, pre_arr_ms=209.600, post_arr_ms=194.700, dt_ms=-14.900, dW=-0.006, W=39.494) (pre_spike_ms=404.600, post_spike_ms=194.600, pre_arr_ms=409.600, post_arr_ms=194.700, dt_ms=-214.900, dW=-0.000, W=39.494)
# Synapse 2: axon_delay_ms=5.0, dend_delay_ms=0.1, #changes=2, init=39.500, final=39.491 => (NoSpikes, dt_ms=0.000, dW=0.000, W=39.500) (pre_spike_ms=204.600, post_spike_ms=204.500, pre_arr_ms=209.600, post_arr_ms=204.600, dt_ms=-5.000, dW=-0.009, W=39.491) (pre_spike_ms=404.600, post_spike_ms=204.500, pre_arr_ms=409.600, post_arr_ms=204.600, dt_ms=-205.000, dW=-0.000, W=39.491)
# ...
